# %%
import pandas as pd

# %%
df = pd.read_csv("CancerClinicalTrialData.csv")

# %%
df_cancer = df[df['Conditions'].str.contains('Cancer')]

# %%
df_cancer

# %%
name = df_cancer['Study Designs'][123]

# %%
name

# %%
A = []
for item in df_cancer['Study Designs']:
    A.append(item.split()[-1])

# %%
len(A)

# %%
df_cancer1 = df_cancer.copy()

# %%
df_cancer1

# %%
df_cancer1['Study Designs'][123].split('|')

# %%
s = df_cancer1['Study Designs'][123].split('|')[1]
s

# %%
s.split(':')[1:][0]

# %%
df_cancer1['Study Designs'][377]
# Out:
# 'Intervention Model: Crossover Assignment|Masking: Triple (Participant, Investigator, Outcomes Assessor)|Primary Purpose: Treatment'

# %%
Alloc =[]
Interv = []
Mask = []
Purp = []
for item in df_cancer1['Study Designs']:
    Alloc_splitted = item.split('|')
        if len(splitted) != 4:
            
    Alloc.append(splitted[0].split(':')[1:][0])
    Interv.append(splitted[1].split(':')[1:][0])
    Mask.append(splitted[2].split(':')[1:][0])
    Purp.append(splitted[3].split(':')[1:][0])

# %%
Alloc =[]
for item in df_cancer1['Study Designs']:
    if 'Allocation' in item:
        Alloc_splitted = item.split('Allocation: ')
        Alloc_splitted_more = Alloc_splitted[1].split('|')
        Alloc.append(Alloc_splitted_more[0])
    else:
        Alloc.append('N/A')

Alloc[377]
# Out:
# 'N/A'

# %%
for item in df_cancer1['Study Designs']:
    if 'Intervention Model: ' not in item:
        print(item)
# Out:
# Allocation: Non-Randomized|Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: N/A|Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Randomized|Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Non-Randomized|Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Randomized|Masking: Quadruple (Participant, Care Provider, Investigator, Outcomes Assessor)|Primary Purpose: Treatment
# Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Randomized|Masking: None (Open Label)|Primary Purpose: Treatment
# Masking: None (Open Label)|Primary Purpose: Treatment
# Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Randomized|Masking: Double (Participant, Investigator)|Primary Purpose: Treatment
# Allocation: Non-Randomized|Masking: None (Open Label)|Primary Purpose: Basic Science
# Allocation: N/A|Masking: None (Open Label)|Primary Purpose: Treatment
# Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Non-Randomized|Masking: None (Open Label)|Primary Purpose: Treatment
# Masking: None (Open Label)|Primary Purpose: Treatment
# Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Non-Randomized|Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Randomized|Masking: None (Open Label)|Primary Purpose: Treatment
# Masking: None (Open Label)|Primary Purpose: Other
# Masking: None (Open Label)|Primary Purpose: Treatment
# Allocation: Non-Randomized|Masking: None (Open Label)|Primary Purpose: Treatment

# %%
Interv =[]
for item in df_cancer1['Study Designs']:
    if 'Intervention Model: ' in item:
        Interv_splitted = item.split('Intervention Model: ')
        Interv_splitted_more = Interv_splitted[1].split('|')
        Interv.append(Interv_splitted_more[0])
    else:
        Interv.append('N/A')

# %%
Interv
# Out:
# ['Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Crossover Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Factorial Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Factorial Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Crossover Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Crossover Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Crossover Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Crossover Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Crossover Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'N/A',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Crossover Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Crossover Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Crossover Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Crossover Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'N/A',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Factorial Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'N/A',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Crossover Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Sequential Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Sequential Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  'Single Group Assignment',
#  'Single Group Assignment',
#  'Parallel Assignment',
#  'Parallel Assignment',
#  ...]

# %%
for item in df_cancer1['Study Designs']:
    if 'Masking: ' not in item:
        print(item)
# Out:
# Allocation: N/A|Intervention Model: Single Group Assignment
# Allocation: N/A|Intervention Model: Single Group Assignment|Primary Purpose: Diagnostic
# Allocation: Randomized|Intervention Model: Single Group Assignment|Primary Purpose: Treatment
# Allocation: N/A|Intervention Model: Single Group Assignment|Primary Purpose: Basic Science
# Allocation: Randomized|Intervention Model: Parallel Assignment|Primary Purpose: Treatment
# Allocation: Randomized|Intervention Model: Parallel Assignment|Primary Purpose: Treatment

# %%
Mask =[]
for item in df_cancer1['Study Designs']:
    if 'Masking: ' in item:
        Mask_splitted = item.split('Masking: ')
        Mask_splitted_more = Mask_splitted[1].split('|')
        Mask.append(Mask_splitted_more[0])
    else:
        Mask.append('N/A')

# %%
counter = 0
for i in Mask:
    if i == 'N/A':
        counter += 1
counter
# Out:
# 6

# %%
for item in df_cancer1['Study Designs']:
    if 'Purpose: ' not in item:
        print(item)
# Out:
# Allocation: N/A|Intervention Model: Single Group Assignment
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Crossover Assignment|Masking: None (Open Label)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Double (Participant, Investigator)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Single (Outcomes Assessor)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)

# %%
Purp =[]
for item in df_cancer1['Study Designs']:
    if 'Purpose: ' in item:
        Purp_splitted = item.split('Purpose: ')
        Purp_splitted_more = Purp_splitted[1].split('|')
        Purp.append(Purp_splitted_more[0])
    else:
        Purp.append('N/A')

# %%
x=set(Purp)
x
# Out:
# {'Basic Science',
#  'Device Feasibility',
#  'Diagnostic',
#  'Health Services Research',
#  'N/A',
#  'Other',
#  'Prevention',
#  'Screening',
#  'Supportive Care',
#  'Treatment'}

# %%
df_cancer1['Allocation'] = Alloc
df_cancer1['Intervention Model'] = Interv
df_cancer1['Masking'] = Mask
df_cancer1['Purpose'] = Purp

# %%
df_cancer1
# Out:
#       Rank                                              Title     Status  \
# 0        1  Immediate-Release Oxycodone Capsules Study in ...  Completed
# 1        2  A Phase II Study of Nivolumab in Combination W...  Completed
# 2        3  Radiation, Cetuximab and Pemetrexed With or Wi...  Completed
# 3        4  Fulvestrant Plus Enzalutamide in ER+/Her2- Adv...  Completed
# 4        5  PROspective Non-interventional Open laBEl Tria...  Completed
# ...    ...                                                ...        ...
# 6283  6284  OHI--Randomized Control Trial to Evaluate Effi...  Completed
# 6297  6298  High vs Low Dose Dexamethasone on Complication...  Completed
# 6302  6303  Deep Versus Moderate Neuromuscular Blockade Du...  Completed
# 6316  6317  Evaluation of Arterial Pressure Based Cardiac ...  Completed
# 6323  6324  Pentoxifylline Treatment in Acute Pancreatitis...  Completed
#
#      Study Results                                         Conditions  \
# 0      Has Results                                             Cancer
# 1      Has Results                                      Breast Cancer
# 2      Has Results                                             Cancer
# 3      Has Results                                      Breast Cancer
# 4      Has Results                                             Cancer
# ...            ...                                                ...
# 6283   Has Results  Accidental Falls|Fall Due to Loss of Equilibri...
# 6297   Has Results  Dexamethasone|Glucocorticoids|Mastectomy|Breas...
# 6302   Has Results  Cholecystitis|Endometriosis|Bowel Obstruction|...
# 6316   Has Results  Esophageal Diseases|Gastrointestinal Diseases|...
# 6323   Has Results  Acute Pancreatitis (AP)|Gallstone Pancreatitis...
#
#                                           Interventions  \
# 0                        Drug: Oxycodone|Drug: Morphine
# 1                    Drug: Nivolumab|Drug: Cabozantinib
# 2     Drug: Bevacizumab|Drug: Cetuximab|Drug: Pemetr...
# 3                   Drug: Fulvestrant with Enzalutamide
# 4                              Drug: Oxycodone/Naloxone
# ...                                                 ...
# 6283                     Device: MBB AFO|Other: Control
# 6297                                Drug: Dexamethasone
# 6302  Procedure: Deep to Moderate NMB|Procedure: Mod...
# 6316     Device: Vigileo Monitor|Device: FloTrac Sensor
# 6323                 Drug: Pentoxifylline|Drug: Placebo
#
#                                        Outcome Measures      Funded Bys  \
# 0     Numerical Rating Scale (NRS)|The Average Dose ...        Industry
# 1     Overall Response Rate|Number of Participants W...  Other|Industry
# 2     2-year Progression-free Survival (PFS)|2-year ...  Other|Industry
# 3     Clinical Benefit Rate of the Combination of En...  Other|U.S. Fed
# 4     Change in Numeric Rating Scales (NRS) Score|Ch...        Industry
# ...                                                 ...             ...
# 6283  Hip Sway Change From Baseline to 6 Months|Ankl...  Other|Industry
# 6297  Transfer to Post-anesthesia Care Unit (PACU)|D...           Other
# 6302  Peak Airway Pressures|Abdominal Insufflation P...  Other|Industry
# 6316       Length of Hospital Stay (LOS) by Participant  Other|Industry
# 6323  Change in C-reactive Protein (C-RP) From Admis...       Other|NIH
#
#                                           Study Designs Start Date  \
# 0     Allocation: Randomized|Intervention Model: Par...     Jan-11
# 1     Allocation: N/A|Intervention Model: Single Gro...  30-Nov-17
# 2     Allocation: Randomized|Intervention Model: Sin...     Oct-08
# 3     Allocation: N/A|Intervention Model: Single Gro...   6-Jul-17
# 4     Allocation: N/A|Intervention Model: Single Gro...     Jul-12
# ...                                                 ...        ...
# 6283  Allocation: Randomized|Intervention Model: Par...     May-16
# 6297  Allocation: Randomized|Intervention Model: Par...  27-Mar-17
# 6302  Allocation: Randomized|Intervention Model: Cro...  27-Dec-16
# 6316  Allocation: Randomized|Intervention Model: Par...     Aug-07
# 6323  Allocation: Randomized|Intervention Model: Par...     May-15
#
#                                               Locations  \
# 0                                                   NaN
# 1     Dana-Farber Cancer Institute, Boston, Massachu...
# 2     University of Pittsburgh Medical Center, Pitts...
# 3     University of Colorado, Aurora, Colorado, Unit...
# 4     13 sites including Yeungnam University Medical...
# ...                                                 ...
# 6283  Baylor College of Medicine, Houston, Texas, Un...
# 6297                Rigshospitalet, Copenhagen, Denmark
# 6302  Stony Brook University Hospital, Stony Brook, ...
# 6316  U.T.M.D. Anderson Cancer Center, Houston, Texa...
# 6323  Mayo Clinic in Rochester, Rochester, Minnesota...
#
#                                               URL  Allocation  \
# 0     https://ClinicalTrials.gov/show/NCT01675622  Randomized
# 1     https://ClinicalTrials.gov/show/NCT03316586         N/A
# 2     https://ClinicalTrials.gov/show/NCT00703976  Randomized
# 3     https://ClinicalTrials.gov/show/NCT02953860         N/A
# 4     https://ClinicalTrials.gov/show/NCT01719757         N/A
# ...                                           ...         ...
# 6283  https://ClinicalTrials.gov/show/NCT02819011  Randomized
# 6297  https://ClinicalTrials.gov/show/NCT03125941  Randomized
# 6302  https://ClinicalTrials.gov/show/NCT02812186  Randomized
# 6316  https://ClinicalTrials.gov/show/NCT00526331  Randomized
# 6323  https://ClinicalTrials.gov/show/NCT02487225  Randomized
#
#            Intervention Model  \
# 0         Parallel Assignment
# 1     Single Group Assignment
# 2     Single Group Assignment
# 3     Single Group Assignment
# 4     Single Group Assignment
# ...                       ...
# 6283      Parallel Assignment
# 6297      Parallel Assignment
# 6302     Crossover Assignment
# 6316      Parallel Assignment
# 6323      Parallel Assignment
#
#                                                 Masking          Purpose
# 0     Quadruple (Participant, Care Provider, Investi...        Treatment
# 1                                     None (Open Label)        Treatment
# 2                                     None (Open Label)       Diagnostic
# 3                                     None (Open Label)        Treatment
# 4                                     None (Open Label)        Treatment
# ...                                                 ...              ...
# 6283                                  None (Open Label)  Supportive Care
# 6297  Quadruple (Participant, Care Provider, Investi...        Treatment
# 6302                               Single (Participant)        Treatment
# 6316                               Single (Participant)        Treatment
# 6323  Quadruple (Participant, Care Provider, Investi...        Treatment
#
# [3650 rows x 16 columns]

# %%
c=0
for item in df_cancer['Outcome Measures']:
    if 'NRS' in item or 'Numerical Rating Scale' in item:
        c += 1
print(c)
# Out:
# 13
